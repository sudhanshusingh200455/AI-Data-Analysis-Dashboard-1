# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Dashboard Libraries Loaded")
# Out:
# Dashboard Libraries Loaded

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
df = pd.read_csv(url)

df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
print("Rows and Columns:", df.shape)
print("\nColumns:")
print(df.columns)

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Rows and Columns: (244, 7)
#
# Columns:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')
#
# Missing Values:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df['day'].value_counts().plot(kind='bar')
plt.title("Customers by Day")
plt.show()

# %%
df['sex'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Gender Distribution")
plt.ylabel("")
plt.show()

# %%
print("AI Generated Insights")
print("- Most customers visited on Saturday.")
print("- Male customers are higher than female customers.")
print("- Dataset contains restaurant billing information.")
print("- Useful for business trend analysis.")
# Out:
# AI Generated Insights
# - Most customers visited on Saturday.
# - Male customers are higher than female customers.
# - Dataset contains restaurant billing information.
# - Useful for business trend analysis.
